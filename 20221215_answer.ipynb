# %%
import numpy as np

# %%
#問題１
def function_01(x):
    return 0.01*x**2+ 0.1*x

# %%
#問題２
import matplotlib.pylab as plt

x=np.arange(0,20.0,0.1)
y=function_01(x)
plt.xlabel("x")
plt.ylabel("f(x)")
plt.plot(x,y)
plt.show()

# %%
#問題３

def numerical_diff(f,x):
    h=1e-4  
    return (f(x+h)-f(x-h)) / (2*h)  #修正

print(numerical_diff(function_01,5))
print(numerical_diff(function_01,10))
# Out:
# 0.1999999999990898
# 0.2999999999986347

# %%
#付録
def tangent_line(f, x):
    d = numerical_diff(f, x)
    print(d)
    y = f(x) - d*x
    return lambda t: d*t + y
     
x = np.arange(0, 20, 0.1)
y = function_０1(x)
plt.xlabel("x")
plt.ylabel("f(x)")

tf = tangent_line(function_０1, 10)
y2 = tf(x)

plt.plot(x, y)
plt.plot(x, y2)
plt.show()
